# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, StringIndexer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

# 1. Tạo SparkSession
spark = SparkSession.builder.appName("SentimentClassification").getOrCreate()

# 2. Đọc dữ liệu
data = spark.read.csv("data/sentiments.csv", header=True, inferSchema=True)

# 3. Loại bỏ hàng bị NULL ở text hoặc sentiment (cẩn thận)
data = data.na.drop(subset=["text", "sentiment"])

# 4. Các bước xử lý
tokenizer = Tokenizer(inputCol="text", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
vectorizer = CountVectorizer(inputCol="filtered", outputCol="features")

# ⚠️ thêm handleInvalid để tránh lỗi
indexer = StringIndexer(inputCol="sentiment", outputCol="label", handleInvalid="keep")

# 5. Mô hình Logistic Regression
lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)

# 6. Pipeline
pipeline = Pipeline(stages=[tokenizer, remover, vectorizer, indexer, lr])

# 7. Tách train/test
train_data, test_data = data.randomSplit([0.8, 0.2], seed=42)

# 8. Train
model = pipeline.fit(train_data)

# 9. Dự đoán
predictions = model.transform(test_data)

# 10. Xem kết quả
predictions.select("text", "label", "prediction").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+
# |text                                                                                                                                               |label|prediction|
# +---------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+
# |  ISG An update to our Feb 20th video review..if it closes below 495 much lower to come soon                                                       |1.0  |1.0       |
# |  The rodeo clown sent BK screaming into the SI weekly red zone...time to peel away before it turns...                                             |1.0  |1.0       |
# | , ES,SPY, Ground Hog Week, distribution at highs..                                                                                                |1.0  |0.0       |
# | ES, S  PAT TWO, update                                                                                                                            |1.0  |1.0       |
# | PCN doulble top at key fib retracement weekly....time to exit ...                                                                                 |1.0  |1.0       |
# | also not very healthy, fell back below DT line after breaking it, SI weak, MACD turning down                                                      |1.0  |0.0       |
# | thinking out loud. 50 mva sub 200 mva- done. Bottoming tails at 61.60 providing obvious stop. Catalyst higher? 29% short interest.                |0.0  |0.0       |
# |"RT @WSJheard: Canâ€™t get your hands on a Nintendo console to play the new version of ""Animal Crossing""? You could always buy Nintendo stockâ€¦"|0.0  |0.0       |
# |#ContrAlert Don't Panic: Wall Street Is Going Crazy For Student oans -- But It's Not a #Bubble -  SM                                               |1.0  |0.0       |
# |#CoronavirusPandemic As bad as #China's economic dive is, the slump is even more perilous for the rest of #Asia.… https://t.co/PuRY8HSD1V          |1.0  |1.0       |
# |#Gold prices slip below Rs 46,000 as #investors book profits amid #coronavirus-led #recession fears https://t.co/fSylAJrUqv                        |1.0  |1.0       |
# |#Sensex, #Nifty climb off day's highs, still up 2%; Key factors driving D-Street higher today https://t.co/jVQcousFp6                              |0.0  |0.0       |
# |#TCS #share price jumps 9% on no #layoffs, #dividend announcements; should you buy, sell or hold the stock https://t.co/ijDFJRDLOl                 |0.0  |0.0       |
# |'Expensive' and 'Cheap' I dive a little deeper for you (new blog post)  nke aapl spy                                                               |0.0  |1.0       |
# |.user BINGO.Can't consider it a buy (personally) until >470 AND VSB. ntil then, a waste of time trying to game it. AAP                             |1.0  |0.0       |
# |2013 ooks Bright for .S. New Vehicle Sales - Blog Posts by Tom ibby | . . Polk F GM TM HMC                                                         |0.0  |1.0       |
# |39.50 on HA is a big intraday level to play off today                                                                                              |0.0  |0.0       |
# |A few names with a Dark Cloud Cover candle pattern: MHO Y SAFT FXS                                                                                 |1.0  |1.0       |
# |A sharp drop in fuel consumption caused by the coronavirus pandemic and exacerbated by a feud between the worldâ€™s lâ€¦ https://t.co/19EeJFLdB6   |1.0  |1.0       |
# |A year end accounts payable increased 43% from 100million to 143million                                                                            |1.0  |1.0       |
# +---------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Đánh giá
evaluator_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
evaluator_prec = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
evaluator_rec = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")

accuracy = evaluator_acc.evaluate(predictions)
precision = evaluator_prec.evaluate(predictions)
recall = evaluator_rec.evaluate(predictions)
f1 = evaluator_f1.evaluate(predictions)

print("📊 Evaluation Results:")
print(f"  ➤ Accuracy  = {accuracy:.4f}")
print(f"  ➤ Precision = {precision:.4f}")
print(f"  ➤ Recall    = {recall:.4f}")
print(f"  ➤ F1 Score  = {f1:.4f}")

print("Confusion Matrix:")
predictions.groupBy("label", "prediction").count().orderBy("label", "prediction").show()

# Dừng Spark
spark.stop()
# Out:
# 📊 Evaluation Results:
#   ➤ Accuracy  = 0.7665
#   ➤ Precision = 0.7658
#   ➤ Recall    = 0.7665
#   ➤ F1 Score  = 0.7660
# Confusion Matrix:
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0|  570|
# |  0.0|       1.0|  122|
# |  0.0|       2.0|    1|
# |  1.0|       0.0|  136|
# |  1.0|       1.0|  280|
# +-----+----------+-----+
